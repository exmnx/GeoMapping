# %%
#Importing Libraries

import pandas as pd
import numpy as np
from geopy.geocoders import Nominatim
import folium

# %%
#reading excel sheet
Jdata=pd.read_excel("/content/JapanOv.xlsx",sheet_name="Trip Overview")
Jdata.head()
# Out:
#    Region Prefectures                     Name of Place  \
# 0  Kansai       Osaka                 Ebisubashi Bridge
# 1  Kansai       Osaka  Donguri Kyowakoku (Ghibli Store)
# 2  Kansai       Osaka                   Hozenji Yokocho
# 3  Kansai       Osaka              Hozenji Temple Osaka
# 4  Kansai       Osaka               Namba Yasaka Shrine
#
#                                        GPS Location  Time opened Time closed  \
# 0  1 Chome Dotonbori, Chuo Ward, Osaka, 542-0071,...    00:00:00    23:59:00
# 1  Japan, 〒542-0085 Osaka, Chuo Ward, Shinsaibash...    10:00:00    18:00:00
# 2  1 Chome-1-6 Namba, Chuo Ward, Osaka, 542-0076,...    00:00:00    23:59:00
# 3  1 Chome-2-16 Namba, Chuo Ward, Osaka, 542-0076...    00:00:00    23:59:00
# 4  2 Chome-9-19 Motomachi, Naniwa Ward, Osaka, 55...    09:00:00    17:00:00
#
#   Closed On   Price Currency  Price in USD  Price in Yen (maximum)  \
# 0        NaN    0.0      USD           0.0                     0.0
# 1        NaN    0.0      USD           0.0                     0.0
# 2        NaN    0.0      USD           0.0                     0.0
# 3        NaN    0.0      USD           0.0                     0.0
# 4        NaN    0.0      USD           0.0                     0.0
#
#   Included in Amazing Pass  Type of Place Located in   Wards  Time Spent  \
# 0                       No     Attraction  Dotonbori    Chuo         NaN
# 1                       No          Store      Namba    Chuo         NaN
# 2                       No  Business Park      Namba    Chuo         NaN
# 3                       No     Attraction      Namba    Chuo         NaN
# 4                       No     Attraction      Nanba  Naniwa         NaN
#
#    Total Cost Hours of Operation Notes             Notes
# 0         NaN                      NaN               NaN
# 1         NaN                      NaN  On the 7th Floor
# 2         NaN                      NaN               NaN
# 3         NaN                      NaN               NaN
# 4         NaN                      NaN               NaN

# %%
#Creating empty variable to populate new columns in data
EmptyVar= np.repeat(0,Jdata.shape[0])

#Creating new columns
Jdata["Latitude"]=EmptyVar
Jdata["Longitude"]=EmptyVar

# %%
#Assgining geolocator
geolocator = Nominatim(user_agent="JdataAPP")
templat=[]
templist=[]
templong=[]

# %%
#Using a for loop to get geolocations of all places in my data sheet using the column name of place
# and using list to store the locations
for x in range(0,len(Jdata['Name of Place'])):
    location = geolocator.geocode(Jdata['Name of Place'][x])
    templist.append(location)
# Out:
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=Hozenji+Yokocho&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=Kyoto+Botanical+Gardens&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=Age.3&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=Age.3&format=json&limit=1

# %%
#Seeing if my list is the proper length, and seeing if the first location lat and long worked
print('The length of this list is ' + str(len(templist)))
print('The dimesions of the dataframe is ' + str(np.shape(Jdata)))
print('The coordinates to the first location are',templist[0].latitude,templist[0].longitude)
# Out:
# The length of this list is 128
# The dimesions of the dataframe is (128, 21)
# The coordinates to the first location are 34.6690683 135.50129473666235

# %%
#Creating for loop to store latitude and longitude in list for all places disregarding the places not found; therefore placign 0s instead

for x in range(0,len(templist)):
  try:
        templat.append(templist[x].latitude)
  except:
        templat.append(0)

# %%
for x in range(0,len(templist)):
   try:
        templong.append(templist[x].longitude)
   except:
        templong.append(0)

# %%
#Assigning values to dataframe columns
Jdata["Longitude"]=templong
Jdata["Latitude"]=templat
Jdata.head()
# Out:
#    Region Prefectures                     Name of Place  \
# 0  Kansai       Osaka                 Ebisubashi Bridge
# 1  Kansai       Osaka  Donguri Kyowakoku (Ghibli Store)
# 2  Kansai       Osaka                   Hozenji Yokocho
# 3  Kansai       Osaka              Hozenji Temple Osaka
# 4  Kansai       Osaka               Namba Yasaka Shrine
#
#                                        GPS Location  Time opened Time closed  \
# 0  1 Chome Dotonbori, Chuo Ward, Osaka, 542-0071,...    00:00:00    23:59:00
# 1  Japan, 〒542-0085 Osaka, Chuo Ward, Shinsaibash...    10:00:00    18:00:00
# 2  1 Chome-1-6 Namba, Chuo Ward, Osaka, 542-0076,...    00:00:00    23:59:00
# 3  1 Chome-2-16 Namba, Chuo Ward, Osaka, 542-0076...    00:00:00    23:59:00
# 4  2 Chome-9-19 Motomachi, Naniwa Ward, Osaka, 55...    09:00:00    17:00:00
#
#   Closed On   Price Currency  Price in USD  ...  Included in Amazing Pass  \
# 0        NaN    0.0      USD           0.0  ...                        No
# 1        NaN    0.0      USD           0.0  ...                        No
# 2        NaN    0.0      USD           0.0  ...                        No
# 3        NaN    0.0      USD           0.0  ...                        No
# 4        NaN    0.0      USD           0.0  ...                        No
#
#    Type of Place Located in   Wards Time Spent  Total Cost  \
# 0     Attraction  Dotonbori    Chuo        NaN         NaN
# 1          Store      Namba    Chuo        NaN         NaN
# 2  Business Park      Namba    Chuo        NaN         NaN
# 3     Attraction      Namba    Chuo        NaN         NaN
# 4     Attraction      Nanba  Naniwa        NaN         NaN
#
#    Hours of Operation Notes             Notes   Latitude   Longitude
# 0                       NaN               NaN  34.669068  135.501295
# 1                       NaN  On the 7th Floor   0.000000    0.000000
# 2                       NaN               NaN  34.667965  135.503318
# 3                       NaN               NaN  34.668017  135.502478
# 4                       NaN               NaN  34.661482  135.496733
#
# [5 rows x 21 columns]

# %%
#Rows in where there is no lat, long ; Assigning it a temporary array to use later
temparray=np.where(Jdata['Latitude']==0)
temparray
# Out:
# (array([  1,   5,   6,  11,  12,  18,  19,  20,  22,  23,  24,  25,  27,
#          32,  33,  37,  44,  50,  52,  53,  54,  56,  58,  61,  62,  64,
#          91,  95,  96, 101, 102, 111, 112, 121, 123, 127]),)

# %%
#All the places whose coordinates were not found by the geolocator
for x in temparray:
  print(Jdata['Name of Place'][x])
# Out:
# 1            Donguri Kyowakoku (Ghibli Store)
# 5                    Railway forgotten market
# 6                  Round1 Stadium Sennichimae
# 11        Shitennoji Honbo (Abbot's Quarters)
# 12                       Redhorse Osaka Wheel
# 18                                  Aqualiner
# 19                      Osakajo Gozabune Pier
# 20                         Robatayaki Isaribi
# 22                             Yakiniku Kitan
# 23                      Unagi Kushiyaki Idumo
# 24                            Gyukatsu Tomita
# 25      Ganzo Butchikiri Sushi Uoshin Minami
# 27                Noodles & Shaved Ice Dogyan
# 32                                 Kuya Falls
# 33     Arashiyama Tsusen South Boarding Area
# 37                              Kotoimo Honpo
# 44                                 Mount Hiei
# 50             Sawano Restaurant (Fruit Cafe)
# 52              MACCHA HOUSE Kyoto Kawaramach
# 53                            Daigo-ji Temple
# 54                          Hakuryū-en Garden
# 56                    Amanohashidate Viewland
# 58              Amanohashidate Kasamatsu Park
# 61                          Wakakusayama Hill
# 62                           Uguisu Waterfall
# 64                        Kawaji Cherry Trees
# 91                     Toyosu Senkyaku Banrai
# 95                      Cross Shinjuku Vision
# 96                              Godzilla Head
# 101                 Ameyoko Shopping District
# 102                 MUJI Ginza Flagship Store
# 111                          Tokyo Summerland
# 112                                 Minoringo
# 121                             ann fragrance
# 123            Cat cafe MoCHA Akihabara Store
# 127                           Chureito Pagoda
# Name: Name of Place, dtype: object

# %%
#New Column in DF to look for lat,long of 0 values
Jdata['Nearby Alternative']=EmptyVar

# %%
#geolocator.geocode('ダルマ峠')

# %%
#This list lists nearby places or fixes the name of the place for the geolocator to work
#Manual input
temporaryList=['Sunshine City Japan','Semba Center','Round1 Osaka','Shitennoji','Osaka Wheel',
               'Osakajo Pier','Osaka Castle','Maguroya Shibata',
               'Hozenji temple Osaka','LUCUA Osaka','Namba Station','Hozenji temple Osaka',
               'Tanimachi 5,Osaka','ダルマ峠','Arashiyama Nakaoshitacho',
               'Honenji, kyoto','Hiei,kyoto','Chudoji Yabunouchicho','Kyoto-Kawaramachi Station','Daigo-ji',
               'Ninose station','Amanohashidate','Amanohashidate','Wakakusayama',
               'Mt. Kasuga, Nara','Nara Prefectural University','豊洲 千客万来','クロス新宿ビジョン',
               'TOHO Cinemas Shinjuku','Ameyoko Center Building','マロニエゲート銀座3',
               '東京サマーランド','Takeshita street','はぁとぴあ原宿入口','cat cafe mocha','mt fuji']

# %%
#Assigning the names above to the new column with proper row alligning with
#respect to their Jdata['Name of Place'] counterparts
for  x in temparray:
     Jdata['Nearby Alternative'][x]=temporaryList
     print(Jdata['Nearby Alternative'][x])
# Out:
# 1              Sunshine City Japan
# 5                     Semba Center
# 6                     Round1 Osaka
# 11                      Shitennoji
# 12                     Osaka Wheel
# 18                    Osakajo Pier
# 19                    Osaka Castle
# 20                Maguroya Shibata
# 22            Hozenji temple Osaka
# 23                     LUCUA Osaka
# 24                   Namba Station
# 25            Hozenji temple Osaka
# 27               Tanimachi 5,Osaka
# 32                            ダルマ峠
# 33        Arashiyama Nakaoshitacho
# 37                  Honenji, kyoto
# 44                      Hiei,kyoto
# 50           Chudoji Yabunouchicho
# 52       Kyoto-Kawaramachi Station
# 53                        Daigo-ji
# 54                  Ninose station
# 56                  Amanohashidate
# 58                  Amanohashidate
# 61                    Wakakusayama
# 62                Mt. Kasuga, Nara
# 64     Nara Prefectural University
# 91                         豊洲 千客万来
# 95                       クロス新宿ビジョン
# 96           TOHO Cinemas Shinjuku
# 101        Ameyoko Center Building
# 102                     マロニエゲート銀座3
# 111                       東京サマーランド
# 112               Takeshita street
# 121                      はぁとぴあ原宿入口
# 123                 cat cafe mocha
# 127                        mt fuji
# Name: Nearby Alternative, dtype: object
# <ipython-input-15-a0a976261abe>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Nearby Alternative'][x]=temporaryList

# %%
templist1=[]
templat1=[]
templong1=[]

# %%
#Finding geolocations of new names (missing lat,long rows)
#Storing in list
for x in range(0,len(temporaryList)):
    location1 = geolocator.geocode(temporaryList[x])
    templist1.append(location1)
# Out:
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=Ninose+station&format=json&limit=1

# %%
#Storing lat,long in temporary variables
for x in range(0,len(templist1)):
  try:
        templat1.append(templist1[x].latitude)
  except:
        templat1.append(0)

for x in range(0,len(templist1)):
   try:
        templong1.append(templist1[x].longitude)
   except:
        templong1.append(0)

# %%
#Assigning new lat, long in columns of missing lat, long.
for x in temparray:
  Jdata["Longitude"][x]=templong1
  Jdata["Latitude"][x]=templat1
# Out:
# <ipython-input-19-7959866f6556>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata["Longitude"][x]=templong1
# <ipython-input-19-7959866f6556>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata["Latitude"][x]=templat1

# %%
#Checking for missing lat, long
np.where(Jdata['Latitude']==0)
# Out:
# (array([], dtype=int64),)

# %%
#Removing white spaces in Prefecture name
for x in range(0,len(Jdata['Prefectures'])):
  Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# Out:
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-21-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")

# %%
#Creating temporary variables for each prefecture with specifc rows
varName=Jdata['Prefectures'].unique()
prefVar={}
k=0
while k<len(varName):
          var1=np.array(np.where(Jdata['Prefectures']==varName[k]))
          value=var1
          prefVar[k]=value
          k+=1

# %%
#Creating temporary variables for each Ward with specifc rows
Jdata['Wards'].unique()
varName1=Jdata['Wards'].unique()
wardVar={}
k=0
while k<len(varName1):
          var2=np.array(np.where(Jdata['Wards']==varName1[k])[0][0])
          value=var2
          wardVar[k]=value
          k+=1

# %%
#add in for loop and function to automatically add in the locations for the different prefects.

def mapFunction(length,prefec1):
    Mappy=folium.Map(location=(Jdata['Latitude'][length[0]], Jdata['Longitude'][length[0]]),zoom_start=12)

    for x in length:
          folium.Marker(
                location=[Jdata['Latitude'][x], Jdata['Longitude'][x]],
                #tooltip="Click here",
                #radius=2, weight=5,
                popup=Jdata["Name of Place"][x],
                #icon=folium.Icon(icon="bridge",prefix='fa'),
          ).add_to(Mappy)


#code for Circle Distancing in meters, to add miles change the number of miles
#Creates % mile circles for each ward in every prefecture map

    for x in range(0,len(Jdata['Wards'].unique())):
          if Jdata['Prefectures'][wardVar[x]]==prefec1:
              tempIndx=wardVar[x]
              miles=1
              radius = 1609.344*miles
              folium.Circle(
                    location=[Jdata['Latitude'][tempIndx], Jdata['Longitude'][tempIndx]],
                    radius=radius,
                    color="black",
                    weight=1,
                    fill_opacity=0.3,
                    opacity=1,
                    fill_color="pink",
                    fill=False,
                    popup="{} miles".format(miles),
              ).add_to(Mappy)


    return(Mappy)

# %%
#mapFunction(length,prefec1); where length is the prefVar[0][0], [1][0], etc with respect
# to Jdata['Prefectures'].unique()
#example:
#prefVar[0][0] = Osaka  ; prefVar[1][0] = Kyoto
#prefVar[2][0] = Nara  ; prefVar[3][0] = Kanagawa
#prefVar[4][0] = Tokyo ; prefVar[5][0] = Ibaraki
#prefVar[6][0] = Yamanashi ;

# %%
mapFunction(prefVar[0][0],'Osaka')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_734dca9bbb703efd00e20dc639e9f8e6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_734dca9bbb703efd00e20dc639e9f8e6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_734dca9bbb703efd00e20dc639e9f8e6 = L.map(
#                 &quot;map_734dca9bbb703efd00e20dc639e9f8e6&quot;,
#                 {
#                     center: [34.6690683, 135.50129473666235],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e13c15aca87532e2d0cc1e52f9b715fe = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_734dca9bbb703efd00e20dc639e9f8e6);
#
#
#             var marker_4ba04a81ffeea3a72812f2f977f3854b = L.marker(
#                 [34.6690683, 135.50129473666235],
#                 {}
#             ).addTo(map_734dca9bbb703efd00e20dc639e9f8e6);
#
#
#         var popup_61b0d29e608b26a55b2f75b6a05de8fa = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b3a3320730415ce3ddd675bee848ea84 = $(`&lt;div id=&quot;html_b3a3320730415ce3ddd675bee848ea84&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ebisubashi Bridge&lt;/div&gt;`)[0];
#                 popup_61b0d29e608b26a55b2f75b6a05de8fa.setContent(html_b3a3320730415ce3ddd675bee848ea84);
#
#
#
#         marker_4ba04a81ffeea3a72812f2f977f3854b.bindPopup(popup_61b0d29e608b26a55b2f75b6a05de8fa)
#         ;
#
#
#
#
#             var marker_cfb442278b53770288960c7ecbbfad35 = L.marker(
#                 [35.72884775, 139.7195457912119],
#                 {}
#             ).addTo(map_734dca9bbb703efd00e20dc639e9f8e6);
#
#
#         var popup_a0ba3c9313bc940371aac14a385058b2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3da3dc906821f53d0e95de0a3f7836ee = $(`&lt;div id=&quot;html_3da3dc906821f53d0e95de0a3f7836ee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Donguri Kyowakoku (Ghibli Store)&lt;/div&gt;`)[0];
#                 popup_a0ba3c9313bc940371aac14a385058b2.setContent(html_3da3dc906821f53d0e95de0a3f7836ee);
#
#
#
#         marker_cfb442278b53770288960c7ecbbfad35.bindPopup(popup_a0ba3c9313bc940371aac14a385058b2)
#         ;
#
#
#
#
#             var marker_64df5766edfac1d357faf9b0bb40a1e5 = L.marker(
#                 [34.6679653, 135.5033179],
#                 {}
#             ).addTo(map_734dca9bbb703efd00e20dc639e9f8e6);
#
#
#         var popup_fd6b6664d50bd004ce67382b71bd0d3f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_34228047bc667bc2329a44146193cb39 = $(`&lt;div id=&quot;html_34228047bc667bc2329a44146193cb39&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hozenji Yokocho&lt;/div&gt;`)[0];
#                 popup_fd6b6664d50bd004ce67382b71bd0d3f.setContent(html_34228047bc667bc2329a44146193cb39);
#
#
#
#         marker_64df5766edfac1d357faf9b0bb40a1e5.bindPopup(popup_fd6b6664d50bd004ce67382b71bd0d3f)
#         ;
#
#
#
#
#             var marker_abd8e119972c2366f4edaaf0d5d48d80 = L.marker(
#                 [34.66801745, 135.50247797627785],
#                 {}
#             ).addTo(map_734dca9bbb703efd00e20dc639e9f8e6);
#
#
#         var popup_d4556e9e1b205452ce42d1df3e90a6d9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_db936b03447c2d72178e3f594e52b4f2 = $(`&lt;div id=&quot;html_db936b03447c2d72178e3f594e52b4f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hozenji Temple Osaka&lt;/div&gt;`)[0];
#                 popup_d4556e9e1b205452ce42d1df3e90a6d9.setContent(html_db936b03447c2d72178e3f594e52b4f2);
#
#
#
#         marker_abd8e119972c2366f4edaaf0d5d48d80.bindPopup(popup_d4556e9e1b205452ce42d1df3e90a6d9)
#         ;
#
#
#
#
#             var marker_dba50f716b48a995bc7da908a797e592 = L.marker(
#                 [34.66148185, 135.49673254078652],
#                 {}
#             ).addTo(map_734dca9bbb703efd00e20dc639e9f8e6);
#
#
#         var popup_af4921bb2eec2bd3807eda19112f4dfd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_419c6979560b03a08b095393fab08835 = $(`&lt;div id=&quot;html_419c6979560b03a08b095393fab08835&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Namba Yasaka Shrine&lt;/div&gt;`)[0];
#                 popup_af4921bb2eec2bd3807eda19112f4dfd.setContent(html_419c6979560b03a08b095393fab08835);
#
#
#
#         marker_dba50f716b48a995bc7da908a797e592.bindPopup(popup_af4921bb2eec2bd3807eda19112f4dfd)
#         ;
#
#
#
#
#             var marker_5a0ccb0c

# %%
mapFunction(prefVar[1][0],'Kyoto')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5f5bb2f9d873d523839862ccab726352 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5f5bb2f9d873d523839862ccab726352&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5f5bb2f9d873d523839862ccab726352 = L.map(
#                 &quot;map_5f5bb2f9d873d523839862ccab726352&quot;,
#                 {
#                     center: [34.950595899999996, 135.74699477160124],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e4dc5eec29a07402f6cf3b8c683816f4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5f5bb2f9d873d523839862ccab726352);
#
#
#             var marker_48534790bafdc1ee0cdccd388b348153 = L.marker(
#                 [34.950595899999996, 135.74699477160124],
#                 {}
#             ).addTo(map_5f5bb2f9d873d523839862ccab726352);
#
#
#         var popup_2eb7fdffd0c2f758f93f3391f6cf30ab = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0bdcd4794d34c8001de84367bd279d80 = $(`&lt;div id=&quot;html_0bdcd4794d34c8001de84367bd279d80&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Jonangu shrine &lt;/div&gt;`)[0];
#                 popup_2eb7fdffd0c2f758f93f3391f6cf30ab.setContent(html_0bdcd4794d34c8001de84367bd279d80);
#
#
#
#         marker_48534790bafdc1ee0cdccd388b348153.bindPopup(popup_2eb7fdffd0c2f758f93f3391f6cf30ab)
#         ;
#
#
#
#
#             var marker_55f64326da59d83632959ee327f96c1f = L.marker(
#                 [34.93947635, 135.77691659593322],
#                 {}
#             ).addTo(map_5f5bb2f9d873d523839862ccab726352);
#
#
#         var popup_a581290bc7b505d2e09dd31b1d24794c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d5ead5660e4535be3fff86159df6440f = $(`&lt;div id=&quot;html_d5ead5660e4535be3fff86159df6440f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Fushimi-Momoyama Castle&lt;/div&gt;`)[0];
#                 popup_a581290bc7b505d2e09dd31b1d24794c.setContent(html_d5ead5660e4535be3fff86159df6440f);
#
#
#
#         marker_55f64326da59d83632959ee327f96c1f.bindPopup(popup_a581290bc7b505d2e09dd31b1d24794c)
#         ;
#
#
#
#
#             var marker_9c8d242e19a9219431c46e0e3aad1323 = L.marker(
#                 [34.967519249999995, 135.77971008109822],
#                 {}
#             ).addTo(map_5f5bb2f9d873d523839862ccab726352);
#
#
#         var popup_5b1fdf23654c6dffa6836e81abfb7e31 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b8b97d4ab4a21d0be4842bdbabc3703e = $(`&lt;div id=&quot;html_b8b97d4ab4a21d0be4842bdbabc3703e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt; Fushimi Inari Taisha&lt;/div&gt;`)[0];
#                 popup_5b1fdf23654c6dffa6836e81abfb7e31.setContent(html_b8b97d4ab4a21d0be4842bdbabc3703e);
#
#
#
#         marker_9c8d242e19a9219431c46e0e3aad1323.bindPopup(popup_5b1fdf23654c6dffa6836e81abfb7e31)
#         ;
#
#
#
#
#             var marker_413135946324fec759d90b0dfd9e9ceb = L.marker(
#                 [35.0759022, 135.6396464],
#                 {}
#             ).addTo(map_5f5bb2f9d873d523839862ccab726352);
#
#
#         var popup_e3bd89c8783a3093a63bd9038f1c3ed6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_34edb99dbfffb8f69fb81fa946f48ccf = $(`&lt;div id=&quot;html_34edb99dbfffb8f69fb81fa946f48ccf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kuya Falls&lt;/div&gt;`)[0];
#                 popup_e3bd89c8783a3093a63bd9038f1c3ed6.setContent(html_34edb99dbfffb8f69fb81fa946f48ccf);
#
#
#
#         marker_413135946324fec759d90b0dfd9e9ceb.bindPopup(popup_e3bd89c8783a3093a63bd9038f1c3ed6)
#         ;
#
#
#
#
#             var marker_7477e7c9b9d4e88187b405bf8f97cc9c = L.marker(
#                 [35.0100073, 135.6788993],
#                 {}
#             ).addTo(map_5f5bb2f9d873d523839862ccab726352);
#
#
#         var popup_7a0728c05dfe00338d6aec74b61a266e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bd7b645b35fc19eec6951fbc9ea156a9 = $(`&lt;div id=&quot;html_bd7b645b35fc19eec6951fbc9ea156a9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Arashiyama Tsusen South Boarding Area &lt;/div&gt;`)[0];
#                 popup_7a0728c05dfe00338d6aec74b61a266e.setContent(html_bd7b645b35fc19eec6951fbc9ea156a9);
#
#
#
#         marker_7477e7c9b9d4e88187b405bf8f97cc9c.bindPopup(popup_7a0728c05dfe00338d6aec74b61a266e)
#         ;

# %%
mapFunction(prefVar[2][0],"Nara")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aa57b886552f0ba92a77616a0e66e88d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aa57b886552f0ba92a77616a0e66e88d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aa57b886552f0ba92a77616a0e66e88d = L.map(
#                 &quot;map_aa57b886552f0ba92a77616a0e66e88d&quot;,
#                 {
#                     center: [34.6822972, 135.844698],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_720d455f504972e4fa232251f7d357cc = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_aa57b886552f0ba92a77616a0e66e88d);
#
#
#             var marker_f32f3af72b3e2801a47edd3ec37b9e3a = L.marker(
#                 [34.6822972, 135.844698],
#                 {}
#             ).addTo(map_aa57b886552f0ba92a77616a0e66e88d);
#
#
#         var popup_4121ce7af57a811caf66842d2d0d9661 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_342e5c496144195911a2f6ae86178745 = $(`&lt;div id=&quot;html_342e5c496144195911a2f6ae86178745&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Manyo Botanical Gardens&lt;/div&gt;`)[0];
#                 popup_4121ce7af57a811caf66842d2d0d9661.setContent(html_342e5c496144195911a2f6ae86178745);
#
#
#
#         marker_f32f3af72b3e2801a47edd3ec37b9e3a.bindPopup(popup_4121ce7af57a811caf66842d2d0d9661)
#         ;
#
#
#
#
#             var marker_9ebca9610a439b823e390f9412f93ee7 = L.marker(
#                 [-6.86735485, 107.60986852808105],
#                 {}
#             ).addTo(map_aa57b886552f0ba92a77616a0e66e88d);
#
#
#         var popup_ce111edef6a3ed38f584065ba219190d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fe39d77b186dee08f158a1d3a3b562a6 = $(`&lt;div id=&quot;html_fe39d77b186dee08f158a1d3a3b562a6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Nara Park&lt;/div&gt;`)[0];
#                 popup_ce111edef6a3ed38f584065ba219190d.setContent(html_fe39d77b186dee08f158a1d3a3b562a6);
#
#
#
#         marker_9ebca9610a439b823e390f9412f93ee7.bindPopup(popup_ce111edef6a3ed38f584065ba219190d)
#         ;
#
#
#
#
#             var marker_5c9df377893871572eccccfc8cd90cd9 = L.marker(
#                 [34.691173, 135.854265],
#                 {}
#             ).addTo(map_aa57b886552f0ba92a77616a0e66e88d);
#
#
#         var popup_e41c2e841349f37cc3b7b07d33ae0259 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0587dea44523229334403deebcb5d364 = $(`&lt;div id=&quot;html_0587dea44523229334403deebcb5d364&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Wakakusayama Hill&lt;/div&gt;`)[0];
#                 popup_e41c2e841349f37cc3b7b07d33ae0259.setContent(html_0587dea44523229334403deebcb5d364);
#
#
#
#         marker_5c9df377893871572eccccfc8cd90cd9.bindPopup(popup_e41c2e841349f37cc3b7b07d33ae0259)
#         ;
#
#
#
#
#             var marker_e19d56696a591ad5974f972325e912d5 = L.marker(
#                 [34.6814199, 135.8526398],
#                 {}
#             ).addTo(map_aa57b886552f0ba92a77616a0e66e88d);
#
#
#         var popup_43f413ed4c130285882c2f1413846922 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_79ac8d00f43662b1e79a80ced62f3007 = $(`&lt;div id=&quot;html_79ac8d00f43662b1e79a80ced62f3007&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Uguisu Waterfall&lt;/div&gt;`)[0];
#                 popup_43f413ed4c130285882c2f1413846922.setContent(html_79ac8d00f43662b1e79a80ced62f3007);
#
#
#
#         marker_e19d56696a591ad5974f972325e912d5.bindPopup(popup_43f413ed4c130285882c2f1413846922)
#         ;
#
#
#
#
#             var marker_32ecfe83d0fceb12b3e773b1f215b8c9 = L.marker(
#                 [34.688243650000004, 135.83975682879614],
#                 {}
#             ).addTo(map_aa57b886552f0ba92a77616a0e66e88d);
#
#
#         var popup_3eb8fa85107c928b4c43d864fe71d056 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7ebf65c940da44f725425679de489f80 = $(`&lt;div id=&quot;html_7ebf65c940da44f725425679de489f80&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tōdai-ji&lt;/div&gt;`)[0];
#                 popup_3eb8fa85107c928b4c43d864fe71d056.setContent(html_7ebf65c940da44f725425679de489f80);
#
#
#
#         marker_32ecfe83d0fceb12b3e773b1f215b8c9.bindPopup(popup_3eb8fa85107c928b4c43d864fe71d056)
#         ;
#
#
#
#
#             var marker_4c716971dfb43214adc6deb91c4fa391 = L.marker(

# %%
mapFunction(prefVar[3][0],'Kanagawa')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_09d52a64c8264468590858c2f7b710dd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_09d52a64c8264468590858c2f7b710dd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_09d52a64c8264468590858c2f7b710dd = L.map(
#                 &quot;map_09d52a64c8264468590858c2f7b710dd&quot;,
#                 {
#                     center: [35.446835899999996, 139.6541830799203],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_69a3924339394217640f1aed3ae93d75 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_09d52a64c8264468590858c2f7b710dd);
#
#
#             var marker_69b4d03569b0b4bf0f891ed88a16e709 = L.marker(
#                 [35.446835899999996, 139.6541830799203],
#                 {}
#             ).addTo(map_09d52a64c8264468590858c2f7b710dd);
#
#
#         var popup_1c3d19ded6f7bf99543d7df47003789a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8124c23e6566526b7b57f394f17ce0f3 = $(`&lt;div id=&quot;html_8124c23e6566526b7b57f394f17ce0f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Gundam Factory Yokohama&lt;/div&gt;`)[0];
#                 popup_1c3d19ded6f7bf99543d7df47003789a.setContent(html_8124c23e6566526b7b57f394f17ce0f3);
#
#
#
#         marker_69b4d03569b0b4bf0f891ed88a16e709.bindPopup(popup_1c3d19ded6f7bf99543d7df47003789a)
#         ;
#
#
#
#
#             var marker_a9cb4a2d16da0403b1d52337856b7b68 = L.marker(
#                 [35.2385536, 139.0449623],
#                 {}
#             ).addTo(map_09d52a64c8264468590858c2f7b710dd);
#
#
#         var popup_94287f78b0b831623e01e63863366825 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_996866d631896223e907619315ba884f = $(`&lt;div id=&quot;html_996866d631896223e907619315ba884f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hakone Kowakien Yunessun&lt;/div&gt;`)[0];
#                 popup_94287f78b0b831623e01e63863366825.setContent(html_996866d631896223e907619315ba884f);
#
#
#
#         marker_a9cb4a2d16da0403b1d52337856b7b68.bindPopup(popup_94287f78b0b831623e01e63863366825)
#         ;
#
#
#
#
#             var marker_9df40c167cf94b82f12ee800734031ff = L.marker(
#                 [35.381339350000005, 139.6467610871698],
#                 {}
#             ).addTo(map_09d52a64c8264468590858c2f7b710dd);
#
#
#         var popup_3c5d90e60995d8aff09c2acd37b6c9d7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_73e9bf20d057f2b7e58243755f5a2812 = $(`&lt;div id=&quot;html_73e9bf20d057f2b7e58243755f5a2812&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Uniqlo Park&lt;/div&gt;`)[0];
#                 popup_3c5d90e60995d8aff09c2acd37b6c9d7.setContent(html_73e9bf20d057f2b7e58243755f5a2812);
#
#
#
#         marker_9df40c167cf94b82f12ee800734031ff.bindPopup(popup_3c5d90e60995d8aff09c2acd37b6c9d7)
#         ;
#
#
#
#
#             var circle_6c79c067861e8060d95e729b9111ff64 = L.circle(
#                 [35.446835899999996, 139.6541830799203],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;pink&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1, &quot;radius&quot;: 1609.344, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_09d52a64c8264468590858c2f7b710dd);
#
#
#         var popup_ae0799ca376e5ec6983c7d9dfcc7f68a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_eb6d9b6a147e6b1fb9f246c210f69736 = $(`&lt;div id=&quot;html_eb6d9b6a147e6b1fb9f246c210f69736&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1 miles&lt;/div&gt;`)[0];
#                 popup_ae0799ca376e5ec6983c7d9dfcc7f68a.setContent(html_eb6d9b6a147e6b1fb9f246c210f69736);
#
#
#
#         circle_6c79c067861e8060d95e729b9111ff64.bindPopup(popup_ae0799ca376e5ec6983c7d9dfcc7f68a)
#         ;
#
#
#
#
#             var circle_91cb69cbab5dbb940d7ef09c44fbecaf = L.circle(
#                 [35.2385536, 139.0449623],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;pink&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&qu

# %%
mapFunction(prefVar[4][0],'Tokyo')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aefa07d31ef968ba9897dfbf2a3a2d94 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aefa07d31ef968ba9897dfbf2a3a2d94&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aefa07d31ef968ba9897dfbf2a3a2d94 = L.map(
#                 &quot;map_aefa07d31ef968ba9897dfbf2a3a2d94&quot;,
#                 {
#                     center: [35.62836475, 139.5182715600324],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1fe3251d75d3683a7f0b7936a5f2a4e7 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_aefa07d31ef968ba9897dfbf2a3a2d94);
#
#
#             var marker_8d0c794261c15e18ac4dd88795cb015a = L.marker(
#                 [35.62836475, 139.5182715600324],
#                 {}
#             ).addTo(map_aefa07d31ef968ba9897dfbf2a3a2d94);
#
#
#         var popup_079b36f1773543e2168dd03a871d0bbe = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4b3d014853b542dfda73c153b2abdd7c = $(`&lt;div id=&quot;html_4b3d014853b542dfda73c153b2abdd7c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;HANA·BIYORI&lt;/div&gt;`)[0];
#                 popup_079b36f1773543e2168dd03a871d0bbe.setContent(html_4b3d014853b542dfda73c153b2abdd7c);
#
#
#
#         marker_8d0c794261c15e18ac4dd88795cb015a.bindPopup(popup_079b36f1773543e2168dd03a871d0bbe)
#         ;
#
#
#
#
#             var marker_330272e5f5b99811c2db10081f39afc3 = L.marker(
#                 [35.649261949999996, 139.6926277194691],
#                 {}
#             ).addTo(map_aefa07d31ef968ba9897dfbf2a3a2d94);
#
#
#         var popup_516f6a8009cb83c63c0dea25ef675686 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bbf8bdc61abc127d7ac7e388e3ef7a1c = $(`&lt;div id=&quot;html_bbf8bdc61abc127d7ac7e388e3ef7a1c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Starbucks Reserve Roastery Tokyo&lt;/div&gt;`)[0];
#                 popup_516f6a8009cb83c63c0dea25ef675686.setContent(html_bbf8bdc61abc127d7ac7e388e3ef7a1c);
#
#
#
#         marker_330272e5f5b99811c2db10081f39afc3.bindPopup(popup_516f6a8009cb83c63c0dea25ef675686)
#         ;
#
#
#
#
#             var marker_7732c9f4a69a38470816eea0ed17ef49 = L.marker(
#                 [35.713403150000005, 139.79551863643445],
#                 {}
#             ).addTo(map_aefa07d31ef968ba9897dfbf2a3a2d94);
#
#
#         var popup_25f9788b8249f89ea21bdb8def358d07 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6a8c43e2d618807ad245b78878da2e3b = $(`&lt;div id=&quot;html_6a8c43e2d618807ad245b78878da2e3b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sensō-ji&lt;/div&gt;`)[0];
#                 popup_25f9788b8249f89ea21bdb8def358d07.setContent(html_6a8c43e2d618807ad245b78878da2e3b);
#
#
#
#         marker_7732c9f4a69a38470816eea0ed17ef49.bindPopup(popup_25f9788b8249f89ea21bdb8def358d07)
#         ;
#
#
#
#
#             var marker_545c2f8d4bd5a625abadffe378a549e0 = L.marker(
#                 [35.5288434, 139.7007102],
#                 {}
#             ).addTo(map_aefa07d31ef968ba9897dfbf2a3a2d94);
#
#
#         var popup_08d8cdb6421ff62cb8c32af7c89ce398 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_62bd24d5396535dc1c3555778b908e7b = $(`&lt;div id=&quot;html_62bd24d5396535dc1c3555778b908e7b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Nakamise-dori Street&lt;/div&gt;`)[0];
#                 popup_08d8cdb6421ff62cb8c32af7c89ce398.setContent(html_62bd24d5396535dc1c3555778b908e7b);
#
#
#
#         marker_545c2f8d4bd5a625abadffe378a549e0.bindPopup(popup_08d8cdb6421ff62cb8c32af7c89ce398)
#         ;
#
#
#
#
#             var marker_af48ac3b561faa19f1e2e769bd72e9e1 = L.marker(
#                 [35.6748417, 139.69962659091632],
#                 {}
#             ).addTo(map_aefa07d31ef968ba9897dfbf2a3a2d94);
#
#
#         var popup_c7622e2c3df1e0a1f967b071a43761d4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_974258d44a30bd8b627fb0c745513127 = $(`&lt;div id=&quot;html_974258d44a30bd8b627fb0c745513127&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Meiji Jingu&lt;/div&gt;`)[0];
#                 popup_c7622e2c3df1e0a1f967b071a43761d4.setContent(html_974258d44a30bd8b627fb0c745513127);
#
#
#
#         marker_af48ac3b561faa19f1e2e769bd72e9e1.bindPopup(popup_c7622e2c3df1e0a1f967b071a43761d4)
#         ;
#
#
#
#
#             var marker_fb1600d10674b109

# %%
mapFunction(prefVar[5][0],'Ibaraki')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_14665f21fa4f10f9c2beb35c9710f7c3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_14665f21fa4f10f9c2beb35c9710f7c3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_14665f21fa4f10f9c2beb35c9710f7c3 = L.map(
#                 &quot;map_14665f21fa4f10f9c2beb35c9710f7c3&quot;,
#                 {
#                     center: [36.40249825, 140.5943062843619],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_94a802e5a0198fdbb15ff117d84afcb0 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_14665f21fa4f10f9c2beb35c9710f7c3);
#
#
#             var marker_f3e603102ccbb57496a289d78ee7bab2 = L.marker(
#                 [36.40249825, 140.5943062843619],
#                 {}
#             ).addTo(map_14665f21fa4f10f9c2beb35c9710f7c3);
#
#
#         var popup_33242dd40b90780e3362957883446308 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bde42c7c43e161a98088aa9e65102c0e = $(`&lt;div id=&quot;html_bde42c7c43e161a98088aa9e65102c0e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hitachi Seaside Park&lt;/div&gt;`)[0];
#                 popup_33242dd40b90780e3362957883446308.setContent(html_bde42c7c43e161a98088aa9e65102c0e);
#
#
#
#         marker_f3e603102ccbb57496a289d78ee7bab2.bindPopup(popup_33242dd40b90780e3362957883446308)
#         ;
#
#
#
#
#             var circle_bc682d1c8f43200842cfa9029e2975d3 = L.circle(
#                 [36.40249825, 140.5943062843619],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;pink&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1, &quot;radius&quot;: 1609.344, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_14665f21fa4f10f9c2beb35c9710f7c3);
#
#
#         var popup_11a505bb4466113ff06324ba7c6f42fb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9d017e22ec715839f1187e45e0fc06ec = $(`&lt;div id=&quot;html_9d017e22ec715839f1187e45e0fc06ec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1 miles&lt;/div&gt;`)[0];
#                 popup_11a505bb4466113ff06324ba7c6f42fb.setContent(html_9d017e22ec715839f1187e45e0fc06ec);
#
#
#
#         circle_bc682d1c8f43200842cfa9029e2975d3.bindPopup(popup_11a505bb4466113ff06324ba7c6f42fb)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
mapFunction(prefVar[6][0],'Yamanashi')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4411de5ddac8a5106e17f842a2768854 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4411de5ddac8a5106e17f842a2768854&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4411de5ddac8a5106e17f842a2768854 = L.map(
#                 &quot;map_4411de5ddac8a5106e17f842a2768854&quot;,
#                 {
#                     center: [35.362799, 138.730781],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bc29c3cca27802d581b50ad803951dcf = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4411de5ddac8a5106e17f842a2768854);
#
#
#             var marker_ce881ae5398812e5b4c0582d56709185 = L.marker(
#                 [35.362799, 138.730781],
#                 {}
#             ).addTo(map_4411de5ddac8a5106e17f842a2768854);
#
#
#         var popup_9bf49aea7b0fdd9b9d1fbcd8bb6c60b7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4072a6f576b58c7a756473373d607dd4 = $(`&lt;div id=&quot;html_4072a6f576b58c7a756473373d607dd4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Chureito Pagoda&lt;/div&gt;`)[0];
#                 popup_9bf49aea7b0fdd9b9d1fbcd8bb6c60b7.setContent(html_4072a6f576b58c7a756473373d607dd4);
#
#
#
#         marker_ce881ae5398812e5b4c0582d56709185.bindPopup(popup_9bf49aea7b0fdd9b9d1fbcd8bb6c60b7)
#         ;
#
#
#
#
#             var circle_786445298c6f5a5424d2abb21696b8e3 = L.circle(
#                 [35.362799, 138.730781],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;pink&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1, &quot;radius&quot;: 1609.344, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_4411de5ddac8a5106e17f842a2768854);
#
#
#         var popup_2ad8136ba7feacb0341504134b346255 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3b1c4202b8cff38619c3cfa9c7a1086e = $(`&lt;div id=&quot;html_3b1c4202b8cff38619c3cfa9c7a1086e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1 miles&lt;/div&gt;`)[0];
#                 popup_2ad8136ba7feacb0341504134b346255.setContent(html_3b1c4202b8cff38619c3cfa9c7a1086e);
#
#
#
#         circle_786445298c6f5a5424d2abb21696b8e3.bindPopup(popup_2ad8136ba7feacb0341504134b346255)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
