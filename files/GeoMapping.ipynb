# %%
#Importing Libraries

import pandas as pd
import numpy as np
from geopy.geocoders import Nominatim
import folium

# %%
#reading excel sheet
Jdata=pd.read_excel("/content/JapanOv.xlsx",sheet_name="Trip Overview")
Jdata.head()
# Out:
#    Region Prefectures                     Name of Place  \
# 0  Kansai       Osaka                 Ebisubashi Bridge
# 1  Kansai       Osaka  Donguri Kyowakoku (Ghibli Store)
# 2  Kansai       Osaka                   Hozenji Yokocho
# 3  Kansai       Osaka              Hozenji Temple Osaka
# 4  Kansai       Osaka               Namba Yasaka Shrine
#
#                                        GPS Location  Time opened Time closed  \
# 0  1 Chome Dotonbori, Chuo Ward, Osaka, 542-0071,...    00:00:00    23:59:00
# 1  Japan, 〒542-0085 Osaka, Chuo Ward, Shinsaibash...    10:00:00    18:00:00
# 2  1 Chome-1-6 Namba, Chuo Ward, Osaka, 542-0076,...    00:00:00    23:59:00
# 3  1 Chome-2-16 Namba, Chuo Ward, Osaka, 542-0076...    00:00:00    23:59:00
# 4  2 Chome-9-19 Motomachi, Naniwa Ward, Osaka, 55...    09:00:00    17:00:00
#
#   Closed On   Price Currency  Price in USD  Price in Yen (maximum)  \
# 0        NaN    0.0      USD           0.0                     0.0
# 1        NaN    0.0      USD           0.0                     0.0
# 2        NaN    0.0      USD           0.0                     0.0
# 3        NaN    0.0      USD           0.0                     0.0
# 4        NaN    0.0      USD           0.0                     0.0
#
#   Included in Amazing Pass  Type of Place Located in   Wards  Time Spent  \
# 0                       No     Attraction  Dotonbori    Chuo         NaN
# 1                       No          Store      Namba    Chuo         NaN
# 2                       No  Business Park      Namba    Chuo         NaN
# 3                       No     Attraction      Namba    Chuo         NaN
# 4                       No     Attraction      Nanba  Naniwa         NaN
#
#    Total Cost Hours of Operation Notes             Notes
# 0         NaN                      NaN               NaN
# 1         NaN                      NaN  On the 7th Floor
# 2         NaN                      NaN               NaN
# 3         NaN                      NaN               NaN
# 4         NaN                      NaN               NaN

# %%
#Creating empty variable to populate new columns in data
EmptyVar= np.repeat(0,Jdata.shape[0])

#Creating new columns
Jdata["Latitude"]=EmptyVar
Jdata["Longitude"]=EmptyVar

# %%
#Assgining geolocator
geolocator = Nominatim(user_agent="JdataAPP")
templat=[]
templist=[]
templong=[]

# %%
#Using a for loop to get geolocations of all places in my data sheet using the column name of place
# and using list to store the locations
for x in range(0,len(Jdata['Name of Place'])):
    location = geolocator.geocode(Jdata['Name of Place'][x])
    templist.append(location)
# Out:
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=Age.3&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=Age.3&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=Roppongi+Hills&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=Unicorn+Gundam+Statue&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=Yumenoshima+Tropical+Greenhouse+Dome&format=json&limit=1

# %%
#Seeing if my list is the proper length, and seeing if the first location lat and long worked
print('The length of this list is ' + str(len(templist)))
print('The dimesions of the dataframe is ' + str(np.shape(Jdata)))
print('The coordinates to the first location are',templist[0].latitude,templist[0].longitude)
# Out:
# The length of this list is 128
# The dimesions of the dataframe is (128, 21)
# The coordinates to the first location are 34.6690683 135.50129473666235

# %%
#Creating for loop to store latitude and longitude in list for all places disregarding the places not found; therefore placign 0s instead

for x in range(0,len(templist)):
  try:
        templat.append(templist[x].latitude)
  except:
        templat.append(0)

# %%
for x in range(0,len(templist)):
   try:
        templong.append(templist[x].longitude)
   except:
        templong.append(0)

# %%
#Assigning values to dataframe columns
Jdata["Longitude"]=templong
Jdata["Latitude"]=templat
Jdata.head()
# Out:
#    Region Prefectures                     Name of Place  \
# 0  Kansai       Osaka                 Ebisubashi Bridge
# 1  Kansai       Osaka  Donguri Kyowakoku (Ghibli Store)
# 2  Kansai       Osaka                   Hozenji Yokocho
# 3  Kansai       Osaka              Hozenji Temple Osaka
# 4  Kansai       Osaka               Namba Yasaka Shrine
#
#                                        GPS Location  Time opened Time closed  \
# 0  1 Chome Dotonbori, Chuo Ward, Osaka, 542-0071,...    00:00:00    23:59:00
# 1  Japan, 〒542-0085 Osaka, Chuo Ward, Shinsaibash...    10:00:00    18:00:00
# 2  1 Chome-1-6 Namba, Chuo Ward, Osaka, 542-0076,...    00:00:00    23:59:00
# 3  1 Chome-2-16 Namba, Chuo Ward, Osaka, 542-0076...    00:00:00    23:59:00
# 4  2 Chome-9-19 Motomachi, Naniwa Ward, Osaka, 55...    09:00:00    17:00:00
#
#   Closed On   Price Currency  Price in USD  ...  Included in Amazing Pass  \
# 0        NaN    0.0      USD           0.0  ...                        No
# 1        NaN    0.0      USD           0.0  ...                        No
# 2        NaN    0.0      USD           0.0  ...                        No
# 3        NaN    0.0      USD           0.0  ...                        No
# 4        NaN    0.0      USD           0.0  ...                        No
#
#    Type of Place Located in   Wards Time Spent  Total Cost  \
# 0     Attraction  Dotonbori    Chuo        NaN         NaN
# 1          Store      Namba    Chuo        NaN         NaN
# 2  Business Park      Namba    Chuo        NaN         NaN
# 3     Attraction      Namba    Chuo        NaN         NaN
# 4     Attraction      Nanba  Naniwa        NaN         NaN
#
#    Hours of Operation Notes             Notes   Latitude   Longitude
# 0                       NaN               NaN  34.669068  135.501295
# 1                       NaN  On the 7th Floor   0.000000    0.000000
# 2                       NaN               NaN  34.667965  135.503318
# 3                       NaN               NaN  34.668017  135.502478
# 4                       NaN               NaN  34.661482  135.496733
#
# [5 rows x 21 columns]

# %%
#places with innaccurate locations found through geomaps created; therefore, making lat,long zero
inaccurateLoc=[13,21,15,60,82,90,92,78,116,76,87,113,104,70,118]
for x in inaccurateLoc:
  Jdata['Latitude'][x]=0.0
  Jdata['Longitude'][x]=0.0
# Out:
# <ipython-input-10-18be77639ee2>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Latitude'][x]=0.0
# <ipython-input-10-18be77639ee2>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Longitude'][x]=0.0
# <ipython-input-10-18be77639ee2>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Latitude'][x]=0.0
# <ipython-input-10-18be77639ee2>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Longitude'][x]=0.0
# <ipython-input-10-18be77639ee2>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Latitude'][x]=0.0
# <ipython-input-10-18be77639ee2>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Longitude'][x]=0.0
# <ipython-input-10-18be77639ee2>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Latitude'][x]=0.0
# <ipython-input-10-18be77639ee2>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Longitude'][x]=0.0
# <ipython-input-10-18be77639ee2>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Latitude'][x]=0.0
# <ipython-input-10-18be77639ee2>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Longitude'][x]=0.0
# <ipython-input-10-18be77639ee2>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Latitude'][x]=0.0
# <ipython-input-10-18be77639ee2>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Longitude'][x]=0.0
# <ipython-input-10-18be77639ee2>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Latitude'][x]=0.0
# <ipython-input-10-18be77639ee2>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Longitude'][x]=0.0
# <ipython-input-10-18be77639ee2>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Latitude'][x]=0.0
# <ipython-input-10-18be77639ee2>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Longitude'][x]=0.0
# <ipython-input-10-18be77639ee2>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Latitude'][x]=0.0
# <ipython-input-10-18be77639ee2>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Longitude'][x]=0.0
# <ipython-input-10-18be77639ee2>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Latitude'][x]=0.0
# <ipython-input-10-18be77639ee2>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Longitude'][x]=0.0
# <ipython-input-10-18be77639ee2>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Latitude'][x]=0.0
# <ipython-input-10-18be77639ee2>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Longitude'][x]=0.0
# <ipython-input-10-18be77639ee2>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Latitude'][x]=0.0
# <ipython-input-10-18be77639ee2>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Longitude'][x]=0.0
# <ipython-input-10-18be77639ee2>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Latitude'][x]=0.0
# <ipython-input-10-18be77639ee2>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Longitude'][x]=0.0
# <ipython-input-10-18be77639ee2>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Latitude'][x]=0.0
# <ipython-input-10-18be77639ee2>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Longitude'][x]=0.0
# <ipython-input-10-18be77639ee2>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Latitude'][x]=0.0
# <ipython-input-10-18be77639ee2>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Longitude'][x]=0.0

# %%
Jdata['Longitude'][13]
# Out:
# 0.0

# %%
#Rows in where there is no lat, long ; Assigning it a temporary array to use later
temparray=np.where(Jdata['Latitude']==0)
temparray
# Out:
# (array([  1,   5,   6,  11,  12,  13,  15,  18,  19,  20,  21,  22,  23,
#          24,  25,  27,  32,  33,  37,  44,  50,  52,  53,  54,  56,  58,
#          60,  61,  62,  64,  70,  76,  78,  82,  87,  90,  91,  92,  95,
#          96, 101, 102, 104, 111, 112, 113, 116, 118, 121, 123, 127]),)

# %%
#All the places whose coordinates were not found by the geolocator
for x in temparray:
  print(Jdata['Name of Place'][x])
# Out:
# 1            Donguri Kyowakoku (Ghibli Store)
# 5                    Railway forgotten market
# 6                  Round1 Stadium Sennichimae
# 11        Shitennoji Honbo (Abbot's Quarters)
# 12                       Redhorse Osaka Wheel
# 13                  Flower Hill (Hana-no-oka)
# 15                      日本庭園; Japanese garden
# 18                                  Aqualiner
# 19                      Osakajo Gozabune Pier
# 20                         Robatayaki Isaribi
# 21               Chibo Okonomiyaki Restaurant
# 22                             Yakiniku Kitan
# 23                      Unagi Kushiyaki Idumo
# 24                            Gyukatsu Tomita
# 25      Ganzo Butchikiri Sushi Uoshin Minami
# 27                Noodles & Shaved Ice Dogyan
# 32                                 Kuya Falls
# 33     Arashiyama Tsusen South Boarding Area
# 37                              Kotoimo Honpo
# 44                                 Mount Hiei
# 50             Sawano Restaurant (Fruit Cafe)
# 52              MACCHA HOUSE Kyoto Kawaramach
# 53                            Daigo-ji Temple
# 54                          Hakuryū-en Garden
# 56                    Amanohashidate Viewland
# 58              Amanohashidate Kasamatsu Park
# 60                                  Nara Park
# 61                          Wakakusayama Hill
# 62                           Uguisu Waterfall
# 64                        Kawaji Cherry Trees
# 70                       Nakamise-dori Street
# 76                                  Ueno Park
# 78                             Yushima Shrine
# 82                              Italia Street
# 87                           MEGA Don Quijote
# 90                                      Age.3
# 91                     Toyosu Senkyaku Banrai
# 92                            Imperial Palace
# 95                      Cross Shinjuku Vision
# 96                              Godzilla Head
# 101                 Ameyoko Shopping District
# 102                 MUJI Ginza Flagship Store
# 104                        Namiki Dōri Street
# 111                          Tokyo Summerland
# 112                                 Minoringo
# 113                 LONG! LONGER!! LONGEST!!!
# 116                              Uniqlo Japan
# 118                               Alpen Tokyo
# 121                             ann fragrance
# 123            Cat cafe MoCHA Akihabara Store
# 127                           Chureito Pagoda
# Name: Name of Place, dtype: object

# %%
#New Column in DF to look for lat,long of 0 values
Jdata['Nearby Alternative']=EmptyVar

# %%
#This list lists nearby places or fixes the name of the place for the geolocator to work
#Manual input
temporaryList=['心斎橋PARCO','Semba Center','Round1 Osaka','Shitennoji','Osaka Wheel',
               'Tower of the Sun','Tower of the Sun','Osakajo Pier','Osaka Castle','Maguroya Shibata',
               '相合橋','Hozenji temple Osaka','LUCUA Osaka','Namba Station','Hozenji temple Osaka',
               'Tanimachi 5,Osaka','ダルマ峠','Arashiyama Nakaoshitacho',
               'Honenji, kyoto','Hiei,kyoto','Chudoji Yabunouchicho','Kyoto-Kawaramachi Station','Daigo-ji',
               'Ninose station','Amanohashidate','Amanohashidate','春日野園地','Wakakusayama',
               'Mt. Kasuga, Nara','Nara Prefectural University','Kaminarimon','Uenokoen','湯島天満宮',
               'Tokyo Twin Parks','shibuya parco','Kyōbashi Park','豊洲 千客万来','皇居',
               'クロス新宿ビジョン','TOHO Cinemas Shinjuku','Ameyoko Center Building','マロニエゲート銀座3',
               'ginza station','東京サマーランド','Takeshita street','Takeshita street',
               'ginza station','Seibu-Shinjuku Station','はぁとぴあ原宿入口','cat cafe mocha','mt fuji']

# %%
#Assigning the names above to the new column with proper row alligning with
#respect to their Jdata['Name of Place'] counterparts
for  x in temparray:
     Jdata['Nearby Alternative'][x]=temporaryList
     print(Jdata['Nearby Alternative'][x])
# Out:
# 1                         心斎橋PARCO
# 5                     Semba Center
# 6                     Round1 Osaka
# 11                      Shitennoji
# 12                     Osaka Wheel
# 13                Tower of the Sun
# 15                Tower of the Sun
# 18                    Osakajo Pier
# 19                    Osaka Castle
# 20                Maguroya Shibata
# 21                             相合橋
# 22            Hozenji temple Osaka
# 23                     LUCUA Osaka
# 24                   Namba Station
# 25            Hozenji temple Osaka
# 27               Tanimachi 5,Osaka
# 32                            ダルマ峠
# 33        Arashiyama Nakaoshitacho
# 37                  Honenji, kyoto
# 44                      Hiei,kyoto
# 50           Chudoji Yabunouchicho
# 52       Kyoto-Kawaramachi Station
# 53                        Daigo-ji
# 54                  Ninose station
# 56                  Amanohashidate
# 58                  Amanohashidate
# 60                           春日野園地
# 61                    Wakakusayama
# 62                Mt. Kasuga, Nara
# 64     Nara Prefectural University
# 70                     Kaminarimon
# 76                        Uenokoen
# 78                           湯島天満宮
# 82                Tokyo Twin Parks
# 87                   shibuya parco
# 90                   Kyōbashi Park
# 91                         豊洲 千客万来
# 92                              皇居
# 95                       クロス新宿ビジョン
# 96           TOHO Cinemas Shinjuku
# 101        Ameyoko Center Building
# 102                     マロニエゲート銀座3
# 104                  ginza station
# 111                       東京サマーランド
# 112               Takeshita street
# 113               Takeshita street
# 116                  ginza station
# 118         Seibu-Shinjuku Station
# 121                      はぁとぴあ原宿入口
# 123                 cat cafe mocha
# 127                        mt fuji
# Name: Nearby Alternative, dtype: object
# <ipython-input-16-a0a976261abe>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Nearby Alternative'][x]=temporaryList

# %%
templist1=[]
templat1=[]
templong1=[]

# %%
#Finding geolocations of new names (missing lat,long rows)
#Storing in list
for x in range(0,len(temporaryList)):
    location1 = geolocator.geocode(temporaryList[x])
    templist1.append(location1)

# %%
#Storing lat,long in temporary variables
for x in range(0,len(templist1)):
  try:
        templat1.append(templist1[x].latitude)
  except:
        templat1.append(0)

for x in range(0,len(templist1)):
   try:
        templong1.append(templist1[x].longitude)
   except:
        templong1.append(0)

# %%
#Assigning new lat, long in columns of missing lat, long.
for x in temparray:
  Jdata["Longitude"][x]=templong1
  Jdata["Latitude"][x]=templat1
# Out:
# <ipython-input-20-7959866f6556>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata["Longitude"][x]=templong1
# <ipython-input-20-7959866f6556>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata["Latitude"][x]=templat1

# %%
#Checking for missing lat, long
np.where(Jdata['Latitude']==0)
# Out:
# (array([], dtype=int64),)

# %%
#Removing white spaces in Prefecture name
for x in range(0,len(Jdata['Prefectures'])):
  Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# Out:
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")
# <ipython-input-22-a64acd02d784>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Jdata['Prefectures'][x]=Jdata['Prefectures'][x].strip(" ")

# %%
#Creating temporary variables for each prefecture with specifc rows
varName=Jdata['Prefectures'].unique()
prefVar={}
k=0
while k<len(varName):
          var1=np.array(np.where(Jdata['Prefectures']==varName[k]))
          value=var1
          prefVar[k]=value
          k+=1

# %%
#Creating temporary variables for each Ward with specifc rows
Jdata['Wards'].unique()
varName1=Jdata['Wards'].unique()
wardVar={}
k=0
while k<len(varName1):
          var2=np.array(np.where(Jdata['Wards']==varName1[k])[0][0])
          value=var2
          wardVar[k]=value
          k+=1

# %%
#add in for loop and function to automatically add in the locations for the different prefects.

def mapFunction(length,prefec1):
    Mappy=folium.Map(location=(Jdata['Latitude'][length[0]], Jdata['Longitude'][length[0]]),zoom_start=12)

    for x in length:
          folium.Marker(
                location=[Jdata['Latitude'][x], Jdata['Longitude'][x]],
                #tooltip="Click here",
                #radius=2, weight=5,
                popup=Jdata["Name of Place"][x],
                #icon=folium.Icon(icon="bridge",prefix='fa'),
          ).add_to(Mappy)


#code for Circle Distancing in meters, to add miles change the number of miles
#Creates % mile circles for each ward in every prefecture map

    for x in range(0,len(Jdata['Wards'].unique())):
          if Jdata['Prefectures'][wardVar[x]]==prefec1:
              tempIndx=wardVar[x]
              miles=1
              radius = 1609.344*miles
              folium.Circle(
                    location=[Jdata['Latitude'][tempIndx], Jdata['Longitude'][tempIndx]],
                    radius=radius,
                    color="black",
                    weight=1,
                    fill_opacity=0.3,
                    opacity=1,
                    fill_color="pink",
                    fill=False,
                    popup="{} miles".format(miles),
              ).add_to(Mappy)


    return(Mappy)

# %%
#mapFunction(length,prefec1); where length is the prefVar[0][0], [1][0], etc with respect
# to Jdata['Prefectures'].unique()
#example:
#prefVar[0][0] = Osaka  ; prefVar[1][0] = Kyoto
#prefVar[2][0] = Nara  ; prefVar[3][0] = Kanagawa
#prefVar[4][0] = Tokyo ; prefVar[5][0] = Ibaraki
#prefVar[6][0] = Yamanashi ;

# %%
mapFunction(prefVar[0][0],'Osaka')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a76d3c9d3b1dcceaaeb4055cae7522d0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a76d3c9d3b1dcceaaeb4055cae7522d0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a76d3c9d3b1dcceaaeb4055cae7522d0 = L.map(
#                 &quot;map_a76d3c9d3b1dcceaaeb4055cae7522d0&quot;,
#                 {
#                     center: [34.6690683, 135.50129473666235],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_616c94d6d655ffe250749e58e50039cd = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a76d3c9d3b1dcceaaeb4055cae7522d0);
#
#
#             var marker_791b3dcfca752ce262f94aae681ab365 = L.marker(
#                 [34.6690683, 135.50129473666235],
#                 {}
#             ).addTo(map_a76d3c9d3b1dcceaaeb4055cae7522d0);
#
#
#         var popup_3797dcaa2f27975e94132a6eead41b48 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_774d0a7f869059f27df46331863a2fa7 = $(`&lt;div id=&quot;html_774d0a7f869059f27df46331863a2fa7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ebisubashi Bridge&lt;/div&gt;`)[0];
#                 popup_3797dcaa2f27975e94132a6eead41b48.setContent(html_774d0a7f869059f27df46331863a2fa7);
#
#
#
#         marker_791b3dcfca752ce262f94aae681ab365.bindPopup(popup_3797dcaa2f27975e94132a6eead41b48)
#         ;
#
#
#
#
#             var marker_4e4964f2644b6db90ad9ef57def65cb8 = L.marker(
#                 [34.6738575, 135.500751],
#                 {}
#             ).addTo(map_a76d3c9d3b1dcceaaeb4055cae7522d0);
#
#
#         var popup_7dc6081e530f2c0dd2ca7bfec09f6c3a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_de97bc667b6c171d9820c6ce8aa49829 = $(`&lt;div id=&quot;html_de97bc667b6c171d9820c6ce8aa49829&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Donguri Kyowakoku (Ghibli Store)&lt;/div&gt;`)[0];
#                 popup_7dc6081e530f2c0dd2ca7bfec09f6c3a.setContent(html_de97bc667b6c171d9820c6ce8aa49829);
#
#
#
#         marker_4e4964f2644b6db90ad9ef57def65cb8.bindPopup(popup_7dc6081e530f2c0dd2ca7bfec09f6c3a)
#         ;
#
#
#
#
#             var marker_7f6dd57b0717fd2ebdd37ff258817266 = L.marker(
#                 [34.6679653, 135.5033179],
#                 {}
#             ).addTo(map_a76d3c9d3b1dcceaaeb4055cae7522d0);
#
#
#         var popup_9ed77d8f45161d5f7d0e5732c6100422 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2b82cfca6f31986f844fa09bfc81d15a = $(`&lt;div id=&quot;html_2b82cfca6f31986f844fa09bfc81d15a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hozenji Yokocho&lt;/div&gt;`)[0];
#                 popup_9ed77d8f45161d5f7d0e5732c6100422.setContent(html_2b82cfca6f31986f844fa09bfc81d15a);
#
#
#
#         marker_7f6dd57b0717fd2ebdd37ff258817266.bindPopup(popup_9ed77d8f45161d5f7d0e5732c6100422)
#         ;
#
#
#
#
#             var marker_bc754312b1e06a02c01f93c93c71a0c1 = L.marker(
#                 [34.66801745, 135.50247797627785],
#                 {}
#             ).addTo(map_a76d3c9d3b1dcceaaeb4055cae7522d0);
#
#
#         var popup_b8f32a238f9c23e04be73b0982dbd23a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5496322e71cfabc5e21e77d7aa7fbd56 = $(`&lt;div id=&quot;html_5496322e71cfabc5e21e77d7aa7fbd56&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hozenji Temple Osaka&lt;/div&gt;`)[0];
#                 popup_b8f32a238f9c23e04be73b0982dbd23a.setContent(html_5496322e71cfabc5e21e77d7aa7fbd56);
#
#
#
#         marker_bc754312b1e06a02c01f93c93c71a0c1.bindPopup(popup_b8f32a238f9c23e04be73b0982dbd23a)
#         ;
#
#
#
#
#             var marker_09a263597ff9d994ef1ca86ecd5b8dab = L.marker(
#                 [34.66148185, 135.49673254078652],
#                 {}
#             ).addTo(map_a76d3c9d3b1dcceaaeb4055cae7522d0);
#
#
#         var popup_2fe8b99144000ef9a1c07fc104051dfe = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c5cce72d602b50980e11a569976f0781 = $(`&lt;div id=&quot;html_c5cce72d602b50980e11a569976f0781&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Namba Yasaka Shrine&lt;/div&gt;`)[0];
#                 popup_2fe8b99144000ef9a1c07fc104051dfe.setContent(html_c5cce72d602b50980e11a569976f0781);
#
#
#
#         marker_09a263597ff9d994ef1ca86ecd5b8dab.bindPopup(popup_2fe8b99144000ef9a1c07fc104051dfe)
#         ;
#
#
#
#
#             var marker_c50aed97fb0fe3b1

# %%
mapFunction(prefVar[1][0],'Kyoto')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d65934503c9e1406f8228ddb6c09a96c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d65934503c9e1406f8228ddb6c09a96c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d65934503c9e1406f8228ddb6c09a96c = L.map(
#                 &quot;map_d65934503c9e1406f8228ddb6c09a96c&quot;,
#                 {
#                     center: [34.950595899999996, 135.74699477160124],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d1bf7235b6a8848a65da63fefba37075 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d65934503c9e1406f8228ddb6c09a96c);
#
#
#             var marker_2c78034f344d979660b124e734b5b0a0 = L.marker(
#                 [34.950595899999996, 135.74699477160124],
#                 {}
#             ).addTo(map_d65934503c9e1406f8228ddb6c09a96c);
#
#
#         var popup_83c9fca840025c3498dcb196b073a696 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_53b37c4bca1cf38ab6b7024c5fb98ff7 = $(`&lt;div id=&quot;html_53b37c4bca1cf38ab6b7024c5fb98ff7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Jonangu shrine &lt;/div&gt;`)[0];
#                 popup_83c9fca840025c3498dcb196b073a696.setContent(html_53b37c4bca1cf38ab6b7024c5fb98ff7);
#
#
#
#         marker_2c78034f344d979660b124e734b5b0a0.bindPopup(popup_83c9fca840025c3498dcb196b073a696)
#         ;
#
#
#
#
#             var marker_7df440b0b42c9a4831d51f8bdec2e66c = L.marker(
#                 [34.93947635, 135.77691659593322],
#                 {}
#             ).addTo(map_d65934503c9e1406f8228ddb6c09a96c);
#
#
#         var popup_8624262a907704f4449f84bd93ded49e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5a568e810abc9b72f5e04e07f7c1f73e = $(`&lt;div id=&quot;html_5a568e810abc9b72f5e04e07f7c1f73e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Fushimi-Momoyama Castle&lt;/div&gt;`)[0];
#                 popup_8624262a907704f4449f84bd93ded49e.setContent(html_5a568e810abc9b72f5e04e07f7c1f73e);
#
#
#
#         marker_7df440b0b42c9a4831d51f8bdec2e66c.bindPopup(popup_8624262a907704f4449f84bd93ded49e)
#         ;
#
#
#
#
#             var marker_be4f8f0f73a5f8073c2b10861a313aae = L.marker(
#                 [34.967519249999995, 135.77971008109822],
#                 {}
#             ).addTo(map_d65934503c9e1406f8228ddb6c09a96c);
#
#
#         var popup_12eea991f23baa2cf7d62f09ae46b6d3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9433bf080227435a1bd336b7b756265d = $(`&lt;div id=&quot;html_9433bf080227435a1bd336b7b756265d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt; Fushimi Inari Taisha&lt;/div&gt;`)[0];
#                 popup_12eea991f23baa2cf7d62f09ae46b6d3.setContent(html_9433bf080227435a1bd336b7b756265d);
#
#
#
#         marker_be4f8f0f73a5f8073c2b10861a313aae.bindPopup(popup_12eea991f23baa2cf7d62f09ae46b6d3)
#         ;
#
#
#
#
#             var marker_30907ab2d75e95b4cad6805eba9c5eea = L.marker(
#                 [35.0759022, 135.6396464],
#                 {}
#             ).addTo(map_d65934503c9e1406f8228ddb6c09a96c);
#
#
#         var popup_d611d354b91e098d44ea3b347e55685f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1aacd3c5a7f3db742924aa598a3e2ea4 = $(`&lt;div id=&quot;html_1aacd3c5a7f3db742924aa598a3e2ea4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kuya Falls&lt;/div&gt;`)[0];
#                 popup_d611d354b91e098d44ea3b347e55685f.setContent(html_1aacd3c5a7f3db742924aa598a3e2ea4);
#
#
#
#         marker_30907ab2d75e95b4cad6805eba9c5eea.bindPopup(popup_d611d354b91e098d44ea3b347e55685f)
#         ;
#
#
#
#
#             var marker_78b4f017da1abd43c7fee6c28895e684 = L.marker(
#                 [35.0100073, 135.6788993],
#                 {}
#             ).addTo(map_d65934503c9e1406f8228ddb6c09a96c);
#
#
#         var popup_5423945b1a3c0704eb6ac2bb49db75ef = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e441779b992f20e55d9c962f0238dd68 = $(`&lt;div id=&quot;html_e441779b992f20e55d9c962f0238dd68&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Arashiyama Tsusen South Boarding Area &lt;/div&gt;`)[0];
#                 popup_5423945b1a3c0704eb6ac2bb49db75ef.setContent(html_e441779b992f20e55d9c962f0238dd68);
#
#
#
#         marker_78b4f017da1abd43c7fee6c28895e684.bindPopup(popup_5423945b1a3c0704eb6ac2bb49db75ef)
#         ;

# %%
mapFunction(prefVar[2][0],"Nara")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3cdfa8ba6679645b445daef276f3aa8b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3cdfa8ba6679645b445daef276f3aa8b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3cdfa8ba6679645b445daef276f3aa8b = L.map(
#                 &quot;map_3cdfa8ba6679645b445daef276f3aa8b&quot;,
#                 {
#                     center: [34.6822972, 135.844698],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5f6dcaf27b0d968d28918e818f91912e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3cdfa8ba6679645b445daef276f3aa8b);
#
#
#             var marker_5eb8f2ecf1518cd61a55f4bde70e538e = L.marker(
#                 [34.6822972, 135.844698],
#                 {}
#             ).addTo(map_3cdfa8ba6679645b445daef276f3aa8b);
#
#
#         var popup_c9b1ceb70e69fe3ff32431faa9b843f6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_508fcbe395408872cfe0300f53574b16 = $(`&lt;div id=&quot;html_508fcbe395408872cfe0300f53574b16&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Manyo Botanical Gardens&lt;/div&gt;`)[0];
#                 popup_c9b1ceb70e69fe3ff32431faa9b843f6.setContent(html_508fcbe395408872cfe0300f53574b16);
#
#
#
#         marker_5eb8f2ecf1518cd61a55f4bde70e538e.bindPopup(popup_c9b1ceb70e69fe3ff32431faa9b843f6)
#         ;
#
#
#
#
#             var marker_56803c4e2b96bb66ef0f4d852a1d3a28 = L.marker(
#                 [34.68553835, 135.8421039448742],
#                 {}
#             ).addTo(map_3cdfa8ba6679645b445daef276f3aa8b);
#
#
#         var popup_2085426d18527659685600179a5fe73d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_512afc163a986bd197530bd6e0f68de6 = $(`&lt;div id=&quot;html_512afc163a986bd197530bd6e0f68de6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Nara Park&lt;/div&gt;`)[0];
#                 popup_2085426d18527659685600179a5fe73d.setContent(html_512afc163a986bd197530bd6e0f68de6);
#
#
#
#         marker_56803c4e2b96bb66ef0f4d852a1d3a28.bindPopup(popup_2085426d18527659685600179a5fe73d)
#         ;
#
#
#
#
#             var marker_dfe618219eb12a0c0456dd373317bcf3 = L.marker(
#                 [34.691173, 135.854265],
#                 {}
#             ).addTo(map_3cdfa8ba6679645b445daef276f3aa8b);
#
#
#         var popup_d0a057acc8ab4cf45b93cf481db5da8e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_785b15609334abf355e9d1adcb6a6942 = $(`&lt;div id=&quot;html_785b15609334abf355e9d1adcb6a6942&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Wakakusayama Hill&lt;/div&gt;`)[0];
#                 popup_d0a057acc8ab4cf45b93cf481db5da8e.setContent(html_785b15609334abf355e9d1adcb6a6942);
#
#
#
#         marker_dfe618219eb12a0c0456dd373317bcf3.bindPopup(popup_d0a057acc8ab4cf45b93cf481db5da8e)
#         ;
#
#
#
#
#             var marker_83c6d04772f959f37f7ffd91caf025f9 = L.marker(
#                 [34.6814199, 135.8526398],
#                 {}
#             ).addTo(map_3cdfa8ba6679645b445daef276f3aa8b);
#
#
#         var popup_43e80c12d5f3c272e361e31439cef946 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_96b4f9c8bcb55cf8a3b73d449bed47b5 = $(`&lt;div id=&quot;html_96b4f9c8bcb55cf8a3b73d449bed47b5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Uguisu Waterfall&lt;/div&gt;`)[0];
#                 popup_43e80c12d5f3c272e361e31439cef946.setContent(html_96b4f9c8bcb55cf8a3b73d449bed47b5);
#
#
#
#         marker_83c6d04772f959f37f7ffd91caf025f9.bindPopup(popup_43e80c12d5f3c272e361e31439cef946)
#         ;
#
#
#
#
#             var marker_c660e4ef540fe53367b52d1dd3b55ac6 = L.marker(
#                 [34.688243650000004, 135.83975682879614],
#                 {}
#             ).addTo(map_3cdfa8ba6679645b445daef276f3aa8b);
#
#
#         var popup_dced0bd7196043a39e6ea79b68859944 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e144a403347857d502feb7ae753d7620 = $(`&lt;div id=&quot;html_e144a403347857d502feb7ae753d7620&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tōdai-ji&lt;/div&gt;`)[0];
#                 popup_dced0bd7196043a39e6ea79b68859944.setContent(html_e144a403347857d502feb7ae753d7620);
#
#
#
#         marker_c660e4ef540fe53367b52d1dd3b55ac6.bindPopup(popup_dced0bd7196043a39e6ea79b68859944)
#         ;
#
#
#
#
#             var marker_cc5cc972bb68d9beefd51e55b0b93ca6 = L.marker(

# %%
mapFunction(prefVar[3][0],'Kanagawa')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6191db1b2968584d181bf181c8f13d09 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6191db1b2968584d181bf181c8f13d09&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6191db1b2968584d181bf181c8f13d09 = L.map(
#                 &quot;map_6191db1b2968584d181bf181c8f13d09&quot;,
#                 {
#                     center: [35.446835899999996, 139.6541830799203],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e7cb7daa80e0a021aa56255b2b8337f3 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6191db1b2968584d181bf181c8f13d09);
#
#
#             var marker_3a047c70c9853598dd05d5ba514031c8 = L.marker(
#                 [35.446835899999996, 139.6541830799203],
#                 {}
#             ).addTo(map_6191db1b2968584d181bf181c8f13d09);
#
#
#         var popup_180b42900af1385a9cc90581b0d90c95 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_856486646ff3c4cbfa1f7d8df551b2c0 = $(`&lt;div id=&quot;html_856486646ff3c4cbfa1f7d8df551b2c0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Gundam Factory Yokohama&lt;/div&gt;`)[0];
#                 popup_180b42900af1385a9cc90581b0d90c95.setContent(html_856486646ff3c4cbfa1f7d8df551b2c0);
#
#
#
#         marker_3a047c70c9853598dd05d5ba514031c8.bindPopup(popup_180b42900af1385a9cc90581b0d90c95)
#         ;
#
#
#
#
#             var marker_fd93c4ba46b56d3089da2a9a5fc424ae = L.marker(
#                 [35.2385536, 139.0449623],
#                 {}
#             ).addTo(map_6191db1b2968584d181bf181c8f13d09);
#
#
#         var popup_806e97c730d93ad77912c31931edecde = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0bf1b6b3b21cb575a21252bc3efed0a4 = $(`&lt;div id=&quot;html_0bf1b6b3b21cb575a21252bc3efed0a4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hakone Kowakien Yunessun&lt;/div&gt;`)[0];
#                 popup_806e97c730d93ad77912c31931edecde.setContent(html_0bf1b6b3b21cb575a21252bc3efed0a4);
#
#
#
#         marker_fd93c4ba46b56d3089da2a9a5fc424ae.bindPopup(popup_806e97c730d93ad77912c31931edecde)
#         ;
#
#
#
#
#             var marker_817a34bbd1a877e09c5070a1ae25cb72 = L.marker(
#                 [35.381339350000005, 139.6467610871698],
#                 {}
#             ).addTo(map_6191db1b2968584d181bf181c8f13d09);
#
#
#         var popup_6838d97d5a43c978300ee2b4773d3142 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b1818e41d1f7bbc97eb60c94da57219a = $(`&lt;div id=&quot;html_b1818e41d1f7bbc97eb60c94da57219a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Uniqlo Park&lt;/div&gt;`)[0];
#                 popup_6838d97d5a43c978300ee2b4773d3142.setContent(html_b1818e41d1f7bbc97eb60c94da57219a);
#
#
#
#         marker_817a34bbd1a877e09c5070a1ae25cb72.bindPopup(popup_6838d97d5a43c978300ee2b4773d3142)
#         ;
#
#
#
#
#             var circle_b5a5663b67f5cac94e4d11cc7f8d4ff0 = L.circle(
#                 [35.446835899999996, 139.6541830799203],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;pink&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1, &quot;radius&quot;: 1609.344, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_6191db1b2968584d181bf181c8f13d09);
#
#
#         var popup_50e2534c7f00c2b54ae1009c57158f9a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e12f7a71ef97d19debe322dda59c320e = $(`&lt;div id=&quot;html_e12f7a71ef97d19debe322dda59c320e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1 miles&lt;/div&gt;`)[0];
#                 popup_50e2534c7f00c2b54ae1009c57158f9a.setContent(html_e12f7a71ef97d19debe322dda59c320e);
#
#
#
#         circle_b5a5663b67f5cac94e4d11cc7f8d4ff0.bindPopup(popup_50e2534c7f00c2b54ae1009c57158f9a)
#         ;
#
#
#
#
#             var circle_914eb559e9e9d994557a5c3df78d9b15 = L.circle(
#                 [35.2385536, 139.0449623],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;pink&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&qu

# %%
mapFunction(prefVar[4][0],'Tokyo')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d9ac1063c032efa20f13521e463c4886 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d9ac1063c032efa20f13521e463c4886&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d9ac1063c032efa20f13521e463c4886 = L.map(
#                 &quot;map_d9ac1063c032efa20f13521e463c4886&quot;,
#                 {
#                     center: [35.62836475, 139.5182715600324],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_209f5c1c0b279c76c75428e646a52fcb = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d9ac1063c032efa20f13521e463c4886);
#
#
#             var marker_3671d157a936f447da220d80131585ac = L.marker(
#                 [35.62836475, 139.5182715600324],
#                 {}
#             ).addTo(map_d9ac1063c032efa20f13521e463c4886);
#
#
#         var popup_ad7d4c34a83dcacd2e4a527ad3a25e94 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e5f3cb0236e430c6a8d0d8af86876cd2 = $(`&lt;div id=&quot;html_e5f3cb0236e430c6a8d0d8af86876cd2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;HANA·BIYORI&lt;/div&gt;`)[0];
#                 popup_ad7d4c34a83dcacd2e4a527ad3a25e94.setContent(html_e5f3cb0236e430c6a8d0d8af86876cd2);
#
#
#
#         marker_3671d157a936f447da220d80131585ac.bindPopup(popup_ad7d4c34a83dcacd2e4a527ad3a25e94)
#         ;
#
#
#
#
#             var marker_84a241e2ec525ddba86beb90e98cd117 = L.marker(
#                 [35.649261949999996, 139.6926277194691],
#                 {}
#             ).addTo(map_d9ac1063c032efa20f13521e463c4886);
#
#
#         var popup_b17f18bf4ccd8382a221ce698ccfac2e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0c04afd3a9d1a36212c259946c5946b3 = $(`&lt;div id=&quot;html_0c04afd3a9d1a36212c259946c5946b3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Starbucks Reserve Roastery Tokyo&lt;/div&gt;`)[0];
#                 popup_b17f18bf4ccd8382a221ce698ccfac2e.setContent(html_0c04afd3a9d1a36212c259946c5946b3);
#
#
#
#         marker_84a241e2ec525ddba86beb90e98cd117.bindPopup(popup_b17f18bf4ccd8382a221ce698ccfac2e)
#         ;
#
#
#
#
#             var marker_be6722c2a40b2891829b6aa4cbcb3d8e = L.marker(
#                 [35.713403150000005, 139.79551863643445],
#                 {}
#             ).addTo(map_d9ac1063c032efa20f13521e463c4886);
#
#
#         var popup_31ce791dd5e48f28e6cb5f74e0fba7f8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_03afd702fd3e85d5484a9ce367f39bac = $(`&lt;div id=&quot;html_03afd702fd3e85d5484a9ce367f39bac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sensō-ji&lt;/div&gt;`)[0];
#                 popup_31ce791dd5e48f28e6cb5f74e0fba7f8.setContent(html_03afd702fd3e85d5484a9ce367f39bac);
#
#
#
#         marker_be6722c2a40b2891829b6aa4cbcb3d8e.bindPopup(popup_31ce791dd5e48f28e6cb5f74e0fba7f8)
#         ;
#
#
#
#
#             var marker_824fce2d943dbeaff1899e03a32b6a9a = L.marker(
#                 [35.7111333, 139.79636829999998],
#                 {}
#             ).addTo(map_d9ac1063c032efa20f13521e463c4886);
#
#
#         var popup_4a74bc5c7d81fb9c3f7861fe619ae9ad = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_031317beb1179fcb7e8da3c72e34588b = $(`&lt;div id=&quot;html_031317beb1179fcb7e8da3c72e34588b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Nakamise-dori Street&lt;/div&gt;`)[0];
#                 popup_4a74bc5c7d81fb9c3f7861fe619ae9ad.setContent(html_031317beb1179fcb7e8da3c72e34588b);
#
#
#
#         marker_824fce2d943dbeaff1899e03a32b6a9a.bindPopup(popup_4a74bc5c7d81fb9c3f7861fe619ae9ad)
#         ;
#
#
#
#
#             var marker_5267ff59d68677c32bed2943fe81c700 = L.marker(
#                 [35.6748417, 139.69962659091632],
#                 {}
#             ).addTo(map_d9ac1063c032efa20f13521e463c4886);
#
#
#         var popup_cc942da204bc766bc9867d8a336d2360 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0ead516983c52d05b5aa6cdc7034388c = $(`&lt;div id=&quot;html_0ead516983c52d05b5aa6cdc7034388c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Meiji Jingu&lt;/div&gt;`)[0];
#                 popup_cc942da204bc766bc9867d8a336d2360.setContent(html_0ead516983c52d05b5aa6cdc7034388c);
#
#
#
#         marker_5267ff59d68677c32bed2943fe81c700.bindPopup(popup_cc942da204bc766bc9867d8a336d2360)
#         ;
#
#
#
#
#             var marker_74ed740b8

# %%
mapFunction(prefVar[5][0],'Ibaraki')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_35e0fe9f058997628a435957026b905b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_35e0fe9f058997628a435957026b905b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_35e0fe9f058997628a435957026b905b = L.map(
#                 &quot;map_35e0fe9f058997628a435957026b905b&quot;,
#                 {
#                     center: [36.40249825, 140.5943062843619],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_376055593821c279e85c71e2935d0e81 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_35e0fe9f058997628a435957026b905b);
#
#
#             var marker_a24ec55f07f8196fce4b2e57f78e200c = L.marker(
#                 [36.40249825, 140.5943062843619],
#                 {}
#             ).addTo(map_35e0fe9f058997628a435957026b905b);
#
#
#         var popup_e6e1ad745b5b3cf5d9249f4bc5beb04d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1a335625586adf36ba119150d68ddcd4 = $(`&lt;div id=&quot;html_1a335625586adf36ba119150d68ddcd4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hitachi Seaside Park&lt;/div&gt;`)[0];
#                 popup_e6e1ad745b5b3cf5d9249f4bc5beb04d.setContent(html_1a335625586adf36ba119150d68ddcd4);
#
#
#
#         marker_a24ec55f07f8196fce4b2e57f78e200c.bindPopup(popup_e6e1ad745b5b3cf5d9249f4bc5beb04d)
#         ;
#
#
#
#
#             var circle_dacc1c4f49cd77f4ae7de5c585c65d35 = L.circle(
#                 [36.40249825, 140.5943062843619],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;pink&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1, &quot;radius&quot;: 1609.344, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_35e0fe9f058997628a435957026b905b);
#
#
#         var popup_cd9ad22c86d4f7f0560f2e0e6a4be524 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9ab192be255168cd791f434c34be8b51 = $(`&lt;div id=&quot;html_9ab192be255168cd791f434c34be8b51&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1 miles&lt;/div&gt;`)[0];
#                 popup_cd9ad22c86d4f7f0560f2e0e6a4be524.setContent(html_9ab192be255168cd791f434c34be8b51);
#
#
#
#         circle_dacc1c4f49cd77f4ae7de5c585c65d35.bindPopup(popup_cd9ad22c86d4f7f0560f2e0e6a4be524)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
mapFunction(prefVar[6][0],'Yamanashi')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b17dcabcfc7382d04f425d12cd1a28d2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b17dcabcfc7382d04f425d12cd1a28d2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b17dcabcfc7382d04f425d12cd1a28d2 = L.map(
#                 &quot;map_b17dcabcfc7382d04f425d12cd1a28d2&quot;,
#                 {
#                     center: [35.362799, 138.730781],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d73889723c4598240614e7fc5545cfe3 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b17dcabcfc7382d04f425d12cd1a28d2);
#
#
#             var marker_8fc176300b0c53a4350d8c056f32b3e1 = L.marker(
#                 [35.362799, 138.730781],
#                 {}
#             ).addTo(map_b17dcabcfc7382d04f425d12cd1a28d2);
#
#
#         var popup_59e165444d04af57dd911fa24efcf4d2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_27cb349be66741c38a21bddce9991b0f = $(`&lt;div id=&quot;html_27cb349be66741c38a21bddce9991b0f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Chureito Pagoda&lt;/div&gt;`)[0];
#                 popup_59e165444d04af57dd911fa24efcf4d2.setContent(html_27cb349be66741c38a21bddce9991b0f);
#
#
#
#         marker_8fc176300b0c53a4350d8c056f32b3e1.bindPopup(popup_59e165444d04af57dd911fa24efcf4d2)
#         ;
#
#
#
#
#             var circle_b2d433e32c0388d80e91f0491d810795 = L.circle(
#                 [35.362799, 138.730781],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;pink&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1, &quot;radius&quot;: 1609.344, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_b17dcabcfc7382d04f425d12cd1a28d2);
#
#
#         var popup_51d837daf6ccd54b782da910961ce85d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3c0127208e8691290bd909379931295a = $(`&lt;div id=&quot;html_3c0127208e8691290bd909379931295a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1 miles&lt;/div&gt;`)[0];
#                 popup_51d837daf6ccd54b782da910961ce85d.setContent(html_3c0127208e8691290bd909379931295a);
#
#
#
#         circle_b2d433e32c0388d80e91f0491d810795.bindPopup(popup_51d837daf6ccd54b782da910961ce85d)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
